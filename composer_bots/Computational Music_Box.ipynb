# %% [markdown]
# ## WELCOME TO THE MUSIC_BOX

# %%
from composer_bots import *
# Out:
# Using TensorFlow backend.

# %%
bach = AI_Composer('Bach')
beethoven = AI_Composer('Beethoven')
chopin = AI_Composer('Chopin')
debussy = AI_Composer('Debussy')
ravel = AI_Composer('Ravel')

# %%
bach.compose()
# Out:
# (8, 128, 300)
#  ____                _       ____          _
# | __ )   __ _   ___ | |__   | __ )   ___  | |_
# |  _ \  / _` | / __|| '_ \  |  _ \  / _ \ | __|
# | |_) || (_| || (__ | | | | | |_) || (_) || |_
# |____/  \__,_| \___||_| |_| |____/  \___/  \__|
#
#
# Hold on, Let me go wake up Bach bot
#
#
# Bach is inventing an idea
#
#
# =========================================================================
# ===================  ================  ==================================
# ===================  ================  ==================================
# ==============  ===  ================  ==================================
# =============    ==  =====  ==  = ===  =  ==  ==  = ====   ==============
# ==============  ===    =======     ==    =======     ==  =  =============
# ==============  ===  =  ==  ==  =  ==   ====  ==  =  ===    =============
# ==============  ===  =  ==  ==  =  ==    ===  ==  =  =====  =============
# =  ==  ==  ===  ===  =  ==  ==  =  ==  =  ==  ==  =  ==  =  ==  ==  ==  =
# =  ==  ==  ===   ==  =  ==  ==  =  ==  =  ==  ==  =  ===   ===  ==  ==  =
# =========================================================================
#
# Bach bot is composing now......
# (◑﹏◐)
# HBox(children=(IntProgress(value=0, max=680), HTML(value='')))
# 128 695
# Bach bot is putting on some finishing touches!
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# _/\/\________/\/\/\/\____/\/\/\/\/\__/\/\/\/\/\/\__/\/\/\/\/\/\__/\/\____/\/\_
# _/\/\__________/\/\____/\/\______________/\/\______/\____________/\/\/\__/\/\_
# _/\/\__________/\/\______/\/\/\/\________/\/\______/\/\/\/\/\____/\/\/\/\/\/\_
# _/\/\__________/\/\____________/\/\______/\/\______/\/\__________/\/\__/\/\/\_
# _/\/\/\/\/\__/\/\/\/\__/\/\/\/\/\________/\/\______/\/\/\/\/\/\__/\/\____/\/\_
# ______________________________________________________________________________
#
#
#
# Lets listen to what he wrote!
#                 <div id='midiPlayerDiv25028'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv25028');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
# Do you like the new composition?
#
#
#          _               _               _                 _                     _            _
#         /\ \            /\ \            / /\              /\ \                  /\ \         /\ \
#        /  \ \          /  \ \          / /  \            /  \ \____             \ \ \        \_\ \
#       / /\ \ \        / /\ \ \        / / /\ \          / /\ \_____\            /\ \_\       /\__ \
#      / / /\ \_\      / / /\ \_\      / / /\ \ \        / / /\/___  /           / /\/_/      / /_ \ \
#     / / /_/ / /     / /_/_ \/_/     / / /  \ \ \      / / /   / / /           / / /        / / /\ \ \
#    / / /__\/ /     / /____/\       / / /___/ /\ \    / / /   / / /           / / /        / / /  \/_/
#   / / /_____/     / /\____\/      / / /_____/ /\ \  / / /   / / /           / / /        / / /
#  / / /\ \ \      / / /______     / /_________/\ \ \ \ \ \__/ / /        ___/ / /__      / / /
# / / /  \ \ \    / / /_______\   / / /_       __\ \_\ \ \___\/ /        /\__\/_/___\    /_/ /
# \/_/    \_\/    \/__________/   \_\___\     /____/_/  \/_____/         \/_________/    \_\/

# %%
beethoven.compose()
# Out:
# (46, 128, 300)
#  ____               _    _                                  ____          _
# | __ )   ___   ___ | |_ | |__    ___  __   __  ___  _ __   | __ )   ___  | |_
# |  _ \  / _ \ / _ \| __|| '_ \  / _ \ \ \ / / / _ \| '_ \  |  _ \  / _ \ | __|
# | |_) ||  __/|  __/| |_ | | | || (_) | \ V / |  __/| | | | | |_) || (_) || |_
# |____/  \___| \___| \__||_| |_| \___/   \_/   \___||_| |_| |____/  \___/  \__|
#
#
# Hold on, Let me go see if Beethoven bot is back from his piano lesson
#
#
# Beethoven bot is brooding over an idea
#
#
# =========================================================================
# ===================  ================  ==================================
# ===================  ================  ==================================
# ==============  ===  ================  ==================================
# =============    ==  =====  ==  = ===  =  ==  ==  = ====   ==============
# ==============  ===    =======     ==    =======     ==  =  =============
# ==============  ===  =  ==  ==  =  ==   ====  ==  =  ===    =============
# ==============  ===  =  ==  ==  =  ==    ===  ==  =  =====  =============
# =  ==  ==  ===  ===  =  ==  ==  =  ==  =  ==  ==  =  ==  =  ==  ==  ==  =
# =  ==  ==  ===   ==  =  ==  ==  =  ==  =  ==  ==  =  ===   ===  ==  ==  =
# =========================================================================
#
# Beethoven bot is composing now......
# \m/(-_-)\m/
# HBox(children=(IntProgress(value=0, max=680), HTML(value='')))
# 128 692
# Beethoven bot is putting on some finishing touches!
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# _/\/\________/\/\/\/\____/\/\/\/\/\__/\/\/\/\/\/\__/\/\/\/\/\/\__/\/\____/\/\_
# _/\/\__________/\/\____/\/\______________/\/\______/\____________/\/\/\__/\/\_
# _/\/\__________/\/\______/\/\/\/\________/\/\______/\/\/\/\/\____/\/\/\/\/\/\_
# _/\/\__________/\/\____________/\/\______/\/\______/\/\__________/\/\__/\/\/\_
# _/\/\/\/\/\__/\/\/\/\__/\/\/\/\/\________/\/\______/\/\/\/\/\/\__/\/\____/\/\_
# ______________________________________________________________________________
#
# Lets listen to what he wrote!
#                 <div id='midiPlayerDiv81831'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv81831');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
# Do you like the new composition?
#
#
#  ______     ______     ______     _____        __     ______
# /\  == \   /\  ___\   /\  __ \   /\  __-.     /\ \   /\__  _\
# \ \  __<   \ \  __\   \ \  __ \  \ \ \/\ \    \ \ \  \/_/\ \/
#  \ \_\ \_\  \ \_____\  \ \_\ \_\  \ \____-     \ \_\    \ \_\
#   \/_/ /_/   \/_____/   \/_/\/_/   \/____/      \/_/     \/_/

# %%
chopin.compose()
# Out:
#   ____  _                    _          ____          _
#  / ___|| |__    ___   _ __  (_) _ __   | __ )   ___  | |_
# | |    | '_ \  / _ \ | '_ \ | || '_ \  |  _ \  / _ \ | __|
# | |___ | | | || (_) || |_) || || | | | | |_) || (_) || |_
#  \____||_| |_| \___/ | .__/ |_||_| |_| |____/  \___/  \__|
#                      |_|
#
# Hold on, Let me go see if Chopin bot is still dreaming
#
#
# Chopin bot is pondering
#
#
# =========================================================================
# ===================  ================  ==================================
# ===================  ================  ==================================
# ==============  ===  ================  ==================================
# =============    ==  =====  ==  = ===  =  ==  ==  = ====   ==============
# ==============  ===    =======     ==    =======     ==  =  =============
# ==============  ===  =  ==  ==  =  ==   ====  ==  =  ===    =============
# ==============  ===  =  ==  ==  =  ==    ===  ==  =  =====  =============
# =  ==  ==  ===  ===  =  ==  ==  =  ==  =  ==  ==  =  ==  =  ==  ==  ==  =
# =  ==  ==  ===   ==  =  ==  ==  =  ==  =  ==  ==  =  ===   ===  ==  ==  =
# =========================================================================
#
# Chopin bot is composing now......
# \m/(-_-)\m/
# HBox(children=(IntProgress(value=0, max=680), HTML(value='')))
# 128 695
# Chopin bot is putting on some finishing touches!
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# _/\/\________/\/\/\/\____/\/\/\/\/\__/\/\/\/\/\/\__/\/\/\/\/\/\__/\/\____/\/\_
# _/\/\__________/\/\____/\/\______________/\/\______/\____________/\/\/\__/\/\_
# _/\/\__________/\/\______/\/\/\/\________/\/\______/\/\/\/\/\____/\/\/\/\/\/\_
# _/\/\__________/\/\____________/\/\______/\/\______/\/\__________/\/\__/\/\/\_
# _/\/\/\/\/\__/\/\/\/\__/\/\/\/\/\________/\/\______/\/\/\/\/\/\__/\/\____/\/\_
# ______________________________________________________________________________
#
#
#
# Lets listen to what he wrote!
#                 <div id='midiPlayerDiv138303'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv138303');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
# Do you like the new composition?
# Do you like the new composition?
#
#
#  ______     ______     ______     _____        __     ______
# /\  == \   /\  ___\   /\  __ \   /\  __-.     /\ \   /\__  _\
# \ \  __<   \ \  __\   \ \  __ \  \ \ \/\ \    \ \ \  \/_/\ \/
#  \ \_\ \_\  \ \_____\  \ \_\ \_\  \ \____-     \ \_\    \ \_\
#   \/_/ /_/   \/_____/   \/_/\/_/   \/____/      \/_/     \/_/

# %%
debussy.compose()
# Out:
# (20, 128, 300)
#  ____         _                               ____          _
# |  _ \   ___ | |__   _   _  ___  ___  _   _  | __ )   ___  | |_
# | | | | / _ \| '_ \ | | | |/ __|/ __|| | | | |  _ \  / _ \ | __|
# | |_| ||  __/| |_) || |_| |\__ \\__ \| |_| | | |_) || (_) || |_
# |____/  \___||_.__/  \__,_||___/|___/ \__, | |____/  \___/  \__|
#                                       |___/
#
# Hold on, Let me fetch Debussy bot from the clouds
# Debussy bot is dreaming up an idea
#
#
# =========================================================================
# ===================  ================  ==================================
# ===================  ================  ==================================
# ==============  ===  ================  ==================================
# =============    ==  =====  ==  = ===  =  ==  ==  = ====   ==============
# ==============  ===    =======     ==    =======     ==  =  =============
# ==============  ===  =  ==  ==  =  ==   ====  ==  =  ===    =============
# ==============  ===  =  ==  ==  =  ==    ===  ==  =  =====  =============
# =  ==  ==  ===  ===  =  ==  ==  =  ==  =  ==  ==  =  ==  =  ==  ==  ==  =
# =  ==  ==  ===   ==  =  ==  ==  =  ==  =  ==  ==  =  ===   ===  ==  ==  =
# =========================================================================
#
# Debussy bot is composing now......
# d(^o^)b¸¸♬·¯·♩¸¸♪·¯·♫¸¸
# HBox(children=(IntProgress(value=0, max=680), HTML(value='')))
# 128 695
# Debussy bot is putting on some finishing touches!
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# _/\/\________/\/\/\/\____/\/\/\/\/\__/\/\/\/\/\/\__/\/\/\/\/\/\__/\/\____/\/\_
# _/\/\__________/\/\____/\/\______________/\/\______/\____________/\/\/\__/\/\_
# _/\/\__________/\/\______/\/\/\/\________/\/\______/\/\/\/\/\____/\/\/\/\/\/\_
# _/\/\__________/\/\____________/\/\______/\/\______/\/\__________/\/\__/\/\/\_
# _/\/\/\/\/\__/\/\/\/\__/\/\/\/\/\________/\/\______/\/\/\/\/\/\__/\/\____/\/\_
# ______________________________________________________________________________
#
#
#
# Lets listen to what he wrote!
#                 <div id='midiPlayerDiv192607'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv192607');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
# Do you like the new composition?
#
#
#          _               _               _                 _                     _            _
#         /\ \            /\ \            / /\              /\ \                  /\ \         /\ \
#        /  \ \          /  \ \          / /  \            /  \ \____             \ \ \        \_\ \
#       / /\ \ \        / /\ \ \        / / /\ \          / /\ \_____\            /\ \_\       /\__ \
#      / / /\ \_\      / / /\ \_\      / / /\ \ \        / / /\/___  /           / /\/_/      / /_ \ \
#     / / /_/ / /     / /_/_ \/_/     / / /  \ \ \      / / /   / / /           / / /        / / /\ \ \
#    / / /__\/ /     / /____/\       / / /___/ /\ \    / / /   / / /           / / /        / / /  \/_/
#   / / /_____/     / /\____\/      / / /_____/ /\ \  / / /   / / /           / / /        / / /
#  / / /\ \ \      / / /______     / /_________/\ \ \ \ \ \__/ / /        ___/ / /__      / / /
# / / /  \ \ \    / / /_______\   / / /_       __\ \_\ \ \___\/ /        /\__\/_/___\    /_/ /
# \/_/    \_\/    \/__________/   \_\___\     /____/_/  \/_____/         \/_________/    \_\/

# %%
ravel.compose()
# Out:
# (5, 128, 300)
#  ____                       _   ____          _
# |  _ \   __ _ __   __  ___ | | | __ )   ___  | |_
# | |_) | / _` |\ \ / / / _ \| | |  _ \  / _ \ | __|
# |  _ < | (_| | \ V / |  __/| | | |_) || (_) || |_
# |_| \_\ \__,_|  \_/   \___||_| |____/  \___/  \__|
#
#
# Hold on, Let me go wake up Ravel bot
#
#
# Ravel bot is unraveling an idea
#
#
# =========================================================================
# ===================  ================  ==================================
# ===================  ================  ==================================
# ==============  ===  ================  ==================================
# =============    ==  =====  ==  = ===  =  ==  ==  = ====   ==============
# ==============  ===    =======     ==    =======     ==  =  =============
# ==============  ===  =  ==  ==  =  ==   ====  ==  =  ===    =============
# ==============  ===  =  ==  ==  =  ==    ===  ==  =  =====  =============
# =  ==  ==  ===  ===  =  ==  ==  =  ==  =  ==  ==  =  ==  =  ==  ==  ==  =
# =  ==  ==  ===   ==  =  ==  ==  =  ==  =  ==  ==  =  ===   ===  ==  ==  =
# =========================================================================
#
# Ravel bot is composing now......
# ✯╾━╤デ╦︻✯
# HBox(children=(IntProgress(value=0, max=680), HTML(value='')))
# 128 694
# Ravel bot is putting on some finishing touches!
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# _/\/\________/\/\/\/\____/\/\/\/\/\__/\/\/\/\/\/\__/\/\/\/\/\/\__/\/\____/\/\_
# _/\/\__________/\/\____/\/\______________/\/\______/\____________/\/\/\__/\/\_
# _/\/\__________/\/\______/\/\/\/\________/\/\______/\/\/\/\/\____/\/\/\/\/\/\_
# _/\/\__________/\/\____________/\/\______/\/\______/\/\__________/\/\__/\/\/\_
# _/\/\/\/\/\__/\/\/\/\__/\/\/\/\/\________/\/\______/\/\/\/\/\/\__/\/\____/\/\_
# ______________________________________________________________________________
#
#
#
# Lets listen to what he wrote!
#                 <div id='midiPlayerDiv246175'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv246175');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
# Do you like the new composition?
#
#
#  ______     ______     ______     _____        __     ______
# /\  == \   /\  ___\   /\  __ \   /\  __-.     /\ \   /\__  _\
# \ \  __<   \ \  __\   \ \  __ \  \ \ \/\ \    \ \ \  \/_/\ \/
#  \ \_\ \_\  \ \_____\  \ \_\ \_\  \ \____-     \ \_\    \ \_\
#   \/_/ /_/   \/_____/   \/_/\/_/   \/____/      \/_/     \/_/

# %% [markdown]
# ### Info about Music_Box
# Music_box is an LSTM based AI midi generator.
#  <br>
# Each bot is trained on the works of the composer they are modeled after.
#  <br>
# A random generator, choses notes and chords as input and the AI composes a new piano peice each time the model is instantiated.

# %% [markdown]
# ### Contact me:
# insta -- @matthew_fiinch
#  <br/><br/>
# medium -- Matthew R Finch
#  <br/><br/>
# github -- FinchMF
